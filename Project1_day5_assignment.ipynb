# %%
#Cryptograpy

# %%
 # !pip install cryptography
# Out:
# Requirement already satisfied: cryptography in /usr/local/lib/python3.6/dist-packages (3.3.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.6/dist-packages (from cryptography) (1.14.4)
# Requirement already satisfied: six>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from cryptography) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.12->cryptography) (2.20)

# %%
 from cryptography.fernet import Fernet

# %%
 def genratePassKey():
    key = Fernet.generate_key()
    print(key)
    print(type(key))
    abc = open("PasswordKey.key",'wb')
    abc.write(key)
    abc.close()

# %%
 genratePassKey()
# Out:
# b'cLHMZk_3LXvzSII96ytNTbJxaqBf0-hUoBtrL1vFw_c='
# <class 'bytes'>

# %%
 def getMyKey():
    abc = open("PasswordKey.key",'rb')
    return abc.read()

# %%
 getMyKey()
# Out:
# b'cLHMZk_3LXvzSII96ytNTbJxaqBf0-hUoBtrL1vFw_c='

# %%
 def getContentFromUser():
    return input("Enter the Content you want to Encrypt in your python Script")

# %%
 getContentFromUser()
# Out:
# Enter the Content you want to Encrypt in your python ScriptI love my India
# 'I love my India'

# %%
 def encryptMessage(message_normal):
    key = getMyKey()
    k = Fernet(key)
    encrypted_Message = k.encrypt(message_normal)
    return encrypted_Message

# %%
 encryptMessage(b" HEY THIS IS MY OTP 6622")
# Out:
# b'gAAAAABf3crtjE-Vug5TEzYmRyMuZFSgERxgB8ManzVph8AaKAWHF7WO9-yTc8I5Q36H_dG_RopgnGEv-Sl2W6kF4OYpeXnV0aGwuqOxeAauu71jH5uo51s='

# %%
 def decryptMessage(message_secret):
    key = getMyKey()
    k = Fernet(key)
    decrypted_Message = k.decrypt(message_secret)
    return decrypted_Message

# %%
 decryptMessage(b'gAAAAABf3crtjE-Vug5TEzYmRyMuZFSgERxgB8ManzVph8AaKAWHF7WO9-yTc8I5Q36H_dG_RopgnGEv-Sl2W6kF4OYpeXnV0aGwuqOxeAauu71jH5uo51s=')
# Out:
# b' HEY THIS IS MY OTP 6622'
